# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/CRNN"
# %ls
# Out:
# /content/drive/My Drive/CRNN
# dataset.py  expr/    pre_trained/  ResNet_BiLSTM_CTC.py  train.py
# demo.py     models/  __pycache__/  synth90k/             utils.py

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# training with VGG_BiLSTM_CTC case insensitive model on synth90k dataset
# !python train.py --adadelta --trainRoot ./synth90k/train --valRoot ./synth90k/val --batchSize 64 --cuda --saveInterval 20000
# Out:
# Namespace(adadelta=True, adam=False, alphabet='0123456789abcdefghijklmnopqrstuvwxyz\';:.-! )"$\\#%,@&/?([]{}+-=*^|', batchSize=64, beta1=0.5, cuda=True, displayInterval=5000, expr_dir='expr', imgH=32, imgW=100, keep_ratio=False, lr=0.01, manualSeed=1234, n_test_disp=10, nepoch=25, ngpu=1, nh=256, pretrained='', random_sample=True, saveInterval=20000, trainRoot='./synth90k/train', valInterval=5000, valRoot='./synth90k/val', workers=2)
# CRNN(
#   (cnn): Sequential(
#     (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu0): ReLU(inplace=True)
#     (pooling0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu1): ReLU(inplace=True)
#     (pooling1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
# training with VGG_BiLSTM_CTC case sensitive model on synth90k dataset
# !python train.py --adadelta --trainRoot ./synth90k/train --valRoot ./synth90k/val --batchSize 64 --cuda --saveInterval 20000
# Out:
# Namespace(adadelta=True, adam=False, alphabet='0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ\';:.-! )"$\\#%,@&/?([]{}+-=*^|', batchSize=64, beta1=0.5, cuda=True, displayInterval=5000, expr_dir='expr', imgH=32, imgW=100, keep_ratio=False, lr=0.01, manualSeed=1234, n_test_disp=10, nepoch=25, ngpu=1, nh=256, pretrained='', random_sample=True, saveInterval=20000, trainRoot='./synth90k/train', valInterval=5000, valRoot='./synth90k/val', workers=2)
# CRNN(
#   (cnn): Sequential(
#     (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu0): ReLU(inplace=True)
#     (pooling0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu1): ReLU(inplace=True)
#     (pooling1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
# training from checkpoint with VGG_BiLSTM_CTC case sensitive model on synth90k dataset
# !python train.py --adadelta --trainRoot ./synth90k/train --valRoot ./synth90k/val --batchSize 64 --cuda --saveInterval 20000 --pretrained pre_trained/netCRNN_synth90k_6_20000.pth
# Out:
# Namespace(adadelta=True, adam=False, alphabet='0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ\';:.-! )"$\\#%,@&/?([]{}+-=*^|', batchSize=64, beta1=0.5, cuda=True, displayInterval=5000, expr_dir='expr', imgH=32, imgW=100, keep_ratio=False, lr=0.01, manualSeed=1234, n_test_disp=10, nepoch=25, ngpu=1, nh=256, pretrained='pre_trained/netCRNN_synth90k_6_20000.pth', random_sample=True, saveInterval=20000, trainRoot='./synth90k/train', valInterval=5000, valRoot='./synth90k/val', workers=2)
# CRNN(
#   (cnn): Sequential(
#     (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu0): ReLU(inplace=True)
#     (pooling0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu1): ReLU(inplace=True)
#     (pooling1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ...

# %%
# training with ResNet_BiLSTM_CTC case sensitive model on synth90k dataset
# !python train.py --adadelta --trainRoot ./synth90k/train --valRoot ./synth90k/val --batchSize 64 --cuda --saveInterval 20000
# Out:
# Namespace(adadelta=True, adam=False, alphabet='0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ\';:.-! )"$\\#%,@&/?([]{}+-=*^|', batchSize=64, beta1=0.5, cuda=True, displayInterval=5000, expr_dir='expr', imgH=32, imgW=100, keep_ratio=False, lr=0.01, manualSeed=1234, n_test_disp=10, nepoch=25, ngpu=1, nh=256, pretrained='', random_sample=True, saveInterval=20000, trainRoot='./synth90k/train', valInterval=5000, valRoot='./synth90k/val', workers=2)
# CRNN(
#   (cnn): ResNet_FeatureExtractor(
#     (ConvNet): ResNet(
#       (conv0_1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn0_1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv0_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn0_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
# ...

# %%
# training from checkpoint with ResNet_BiLSTM_CTC case sensitive model on synth90k dataset
# !python train.py --adadelta --trainRoot ./synth90k/train --valRoot ./synth90k/val --batchSize 64 --cuda --saveInterval 20000 --pretrained pre_trained/resnet1.pth
# Out:
# Namespace(adadelta=True, adam=False, alphabet='0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ\';:.-! )"$\\#%,@&/?([]{}+-=*^|', batchSize=64, beta1=0.5, cuda=True, displayInterval=5000, expr_dir='expr', imgH=32, imgW=100, keep_ratio=False, lr=0.01, manualSeed=1234, n_test_disp=10, nepoch=25, ngpu=1, nh=256, pretrained='pre_trained/resnet1.pth', random_sample=True, saveInterval=20000, trainRoot='./synth90k/train', valInterval=5000, valRoot='./synth90k/val', workers=2)
# CRNN(
#   (cnn): ResNet_FeatureExtractor(
#     (ConvNet): ResNet(
#       (conv0_1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn0_1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv0_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn0_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
# ...
